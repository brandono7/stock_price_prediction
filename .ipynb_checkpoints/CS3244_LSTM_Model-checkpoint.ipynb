# %%
import pandas as pd
import numpy as np
import os
import time
from sklearn.model_selection import train_test_split

# %%
combined_stocks_df = pd.read_csv("filtered_stocks_combined.csv")

combined_stocks_df
# Out:
#              Date     index    Open    High     Low   Close     Volume  \
# 0      2011-01-03     45725  41.600  42.293  41.600  42.204  123930383
# 1      2011-01-04     45726  42.579  42.579  42.023  42.426   86135637
# 2      2011-01-05     45727  42.260  42.817  42.196  42.772   70669988
# 3      2011-01-06     45728  42.902  42.932  42.632  42.739   83619699
# 4      2011-01-07     45729  42.787  43.073  42.503  43.045   86506108
# ...           ...       ...     ...     ...     ...     ...        ...
# 75495  2016-12-23  14745947  87.556  87.625  87.201  87.383    4428429
# 75496  2016-12-27  14745948  87.499  87.768  87.257  87.423    5100402
# 75497  2016-12-28  14745949  87.354  87.768  86.949  86.989    6834213
# 75498  2016-12-29  14745950  86.797  87.277  86.728  87.036    6938299
# 75499  2016-12-30  14745951  86.728  87.373  86.710  86.949    9464343
#
#        OpenInt ticker
# 0            0   AAPL
# 1            0   AAPL
# 2            0   AAPL
# 3            0   AAPL
# 4            0   AAPL
# ...        ...    ...
# 75495        0    XOM
# 75496        0    XOM
# 75497        0    XOM
# 75498        0    XOM
# 75499        0    XOM
#
# [75500 rows x 9 columns]

# %%
# Convert Date to datetime and set as index
combined_stocks_df["Date"] = pd.to_datetime(combined_stocks_df["Date"])
combined_stocks_df.set_index("Date", inplace=True)

# Drop unnecessary columns if any
combined_stocks_df = combined_stocks_df.drop(columns=["index"])  # Optional

# Pivot to multi-level columns: Ticker as level 1, feature as level 2
stocks_df = combined_stocks_df.pivot_table(
    index=combined_stocks_df.index,
    columns="ticker",
    values=[col for col in combined_stocks_df.columns if col != "ticker"]
)

# Sort columns for clarity
stocks_df = stocks_df.sort_index(axis=1, level=0)

# Swap the column MultiIndex levels
stocks_df_leveled = stocks_df.swaplevel(axis=1)

# Sort by ticker (Level 0)
stocks_df_leveled = stocks_df_leveled.sort_index(axis=1, level=0)

# Preview the new structure
stocks_df_leveled.head()
# Out:
# ticker        AAPL                                                  ABT  \
#              Close    High     Low    Open OpenInt       Volume   Close
# Date
# 2011-01-03  42.204  42.293  41.600  41.600     0.0  123930383.0  19.358
# 2011-01-04  42.426  42.579  42.023  42.579     0.0   86135637.0  19.540
# 2011-01-05  42.772  42.817  42.196  42.260     0.0   70669988.0  19.540
# 2011-01-06  42.739  42.932  42.632  42.902     0.0   83619699.0  19.500
# 2011-01-07  43.045  43.073  42.503  42.787     0.0   86506108.0  19.582
#
# ticker                              ...     WMT                              \
#               High     Low    Open  ...     Low    Open OpenInt      Volume
# Date                                ...
# 2011-01-03  19.549  19.338  19.549  ...  46.027  46.089     0.0  16789275.0
# 2011-01-04  19.561  19.350  19.448  ...  46.139  46.419     0.0  14296931.0
# 2011-01-05  19.764  19.460  19.520  ...  46.174  46.539     0.0  16723328.0
# 2011-01-06  19.682  19.342  19.634  ...  45.712  46.166     0.0  18335156.0
# 2011-01-07  19.615  19.444  19.489  ...  45.698  45.810     0.0   9374462.0
#
# ticker         XOM
#              Close    High     Low    Open OpenInt      Volume
# Date
# 2011-01-03  60.341  60.535  59.604  59.668     0.0  28807445.0
# 2011-01-04  60.625  60.665  60.235  60.469     0.0  24744869.0
# 2011-01-05  60.462  60.600  60.009  60.430     0.0  20448359.0
# 2011-01-06  60.853  61.052  60.439  60.625     0.0  27829692.0
# 2011-01-07  61.182  61.431  60.777  60.876     0.0  23838996.0
#
# [5 rows x 300 columns]

# %%
# 3. Time-based split into 60% train, 20% val, 20% test
train_dict, val_dict, test_dict = {}, {}, {}

for ticker in stocks_df_leveled.columns.levels[0]:
    stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
    stocks_df_leveled[ticker]['Close'] / stocks_df_leveled[ticker]['Close'].shift(1)
)
    stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
        stocks_df_leveled[ticker]["log_return"].shift(-1)
    )

    # RSI
    delta = stocks_df_leveled[ticker]["Close"].diff()
    gain = np.where(delta > 0, delta, 0)
    loss = np.where(delta < 0, -delta, 0)
    avg_gain = pd.Series(gain, index=stocks_df_leveled.index).rolling(window=14, min_periods=3).mean()
    avg_loss = pd.Series(loss, index=stocks_df_leveled.index).rolling(window=14, min_periods=3).mean()
    rs = avg_gain / (avg_loss + 1e-10)
    stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))

    # Momentum
    stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
        stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Close"].shift(7)
    )

    # Additional Features
    stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
    stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
    stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
    stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
    stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
    stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()


    df = stocks_df_leveled[ticker].dropna().sort_index()
    total_len = len(df)
    train_end = int(total_len * 0.6)
    val_end = train_end + int(total_len * 0.2)

    train_dict[ticker] = df.iloc[:train_end]
    val_dict[ticker] = df.iloc[train_end:val_end]
    test_dict[ticker] = df.iloc[val_end:]

train_df = pd.concat(train_dict, names=["Ticker", "Date"])
val_df = pd.concat(val_dict, names=["Ticker", "Date"])
test_df = pd.concat(test_dict, names=["Ticker", "Date"])

train_df
# Out:
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# ...
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, 'log_return')] = np.log(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "log_return_dir_tomorrow")] = np.sign(
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "RSI")] = 100 - (100 / (1 + rs))
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Momentum")] = (
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Range")] = stocks_df_leveled[ticker]["High"] - stocks_df_leveled[ticker]["Low"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Price_Change")] = stocks_df_leveled[ticker]["Close"] - stocks_df_leveled[ticker]["Open"]
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_3d")] = stocks_df_leveled[ticker]["log_return"].rolling(3).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Volatility_7d")] = stocks_df_leveled[ticker]["log_return"].rolling(7).std()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_5")] = stocks_df_leveled[ticker]["Close"].rolling(5).mean()
# C:\Users\chengmao\AppData\Local\Temp\ipykernel_39736\1246436909.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_df_leveled.loc[:, (ticker, "Rolling_Avg_10")] = stocks_df_leveled[ticker]["Close"].rolling(10).mean()
#                     Close    High     Low    Open  OpenInt       Volume  \
# Ticker Date
# AAPL   2011-01-14  44.627  44.627  44.110  44.310      0.0   85758149.0
#        2011-01-18  43.624  44.152  41.748  41.882      0.0  519250098.0
#        2011-01-19  43.394  44.644  43.140  44.641      0.0  315973540.0
#        2011-01-20  42.605  43.321  42.275  43.053      0.0  213000203.0
#        2011-01-21  41.840  42.887  41.829  42.772      0.0  210098152.0
# ...                   ...     ...     ...     ...      ...          ...
# XOM    2014-08-07  86.507  87.889  85.944  87.828      0.0   11379351.0
#        2014-08-08  87.800  87.847  86.551  86.947      0.0   12730751.0
#        2014-08-11  87.517  88.128  87.342  88.004      0.0    9696158.0
#        2014-08-12  87.305  87.481  86.712  87.055      0.0   10811870.0
#        2014-08-13  87.838  88.032  87.296  87.685      0.0    8629596.0
#
#                    log_return  log_return_dir_tomorrow        RSI  Momentum  \
# Ticker Date
# AAPL   2011-01-14    0.008100                     -1.0  94.953618     1.855
#        2011-01-18   -0.022732                     -1.0  69.199567     0.885
#        2011-01-19   -0.005286                     -1.0  65.147658     0.349
#        2011-01-20   -0.018350                     -1.0  54.250583    -1.250
#        2011-01-21   -0.018119                      1.0  46.680044    -1.912
# ...                       ...                      ...        ...       ...
# XOM    2014-08-07   -0.007210                      1.0  34.226788    -4.642
#        2014-08-08    0.014836                     -1.0  39.040536    -3.090
#        2014-08-11   -0.003228                     -1.0  36.410679     0.419
#        2014-08-12   -0.002425                      1.0  32.716575     0.331
#        2014-08-13    0.006086                      0.0  35.238450    -0.307
#
#                    Range  Price_Change  Volatility_3d  Volatility_7d  \
# Ticker Date
# AAPL   2011-01-14  0.517         0.317       0.002600       0.006968
#        2011-01-18  2.404         1.742       0.016654       0.012942
#        2011-01-19  1.504        -1.247       0.015460       0.013119
#        2011-01-20  1.046        -0.448       0.009076       0.012327
#        2011-01-21  1.058        -0.932       0.007476       0.013346
# ...                  ...           ...            ...            ...
# XOM    2014-08-07  1.945        -1.321       0.013726       0.018748
#        2014-08-08  1.296         0.853       0.011276       0.020576
#        2014-08-11  0.786        -0.487       0.011749       0.012263
#        2014-08-12  0.769         0.250       0.010206       0.012297
#        2014-08-13  0.736         0.153       0.005162       0.011298
#
#                    Rolling_Avg_5  Rolling_Avg_10
# Ticker Date
# AAPL   2011-01-14        44.1218         43.3795
#        2011-01-18        44.0756         43.5215
#        2011-01-19        44.0040         43.6183
#        2011-01-20        43.7034         43.6016
#        2011-01-21        43.2180         43.5117
# ...                          ...             ...
# XOM    2014-08-07        87.0408         88.7061
#        2014-08-08        87.2060         88.4023
#        2014-08-11        87.0804         87.9658
#        2014-08-12        87.2524         87.5814
#        2014-08-13        87.3934         87.2762
#
# [45000 rows x 16 columns]

# %% [markdown]
# ## LSTM Model

# %%
# !pip install keras-tuner
# !pip install tensorflow

# %%
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras import Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight
from sklearn.utils import shuffle

# %%
# Function to create sequences for LSTM input
def create_sequences(df, seq_length=10):
    X, y = [], []
    for i in range(len(df) - seq_length):
        X.append(df.iloc[i:i+seq_length, :-1].values)  # Features (excluding target)
        y.append(1 if df.iloc[i+seq_length, -1] > 0 else 0)  # Label: 1 (Long) or 0 (Short)
    return np.array(X), np.array(y)

# Select relevant columns for modeling
# features = ["Close", "High", "Low", "Open", "Volume", "log_return"]
features = ["Close","High","Low","Open","OpenInt","Volume","log_return","RSI","Momentum","Range","Price_Change","Volatility_3d",  "Volatility_7d",
    "Rolling_Avg_5","Rolling_Avg_10"]
target = ["log_return_dir_tomorrow"]
# target = ["log_return"]

# Normalize features
scaler = StandardScaler()
train_df[features] = scaler.fit_transform(train_df[features])
val_df[features] = scaler.transform(val_df[features])
test_df[features] = scaler.transform(test_df[features])

# Create sequences
seq_length = 10  # Use past 10 days to predict next day
X_train, y_train = create_sequences(train_df[features + target], seq_length)
X_val, y_val = create_sequences(val_df[features + target], seq_length)
X_test, y_test = create_sequences(test_df[features + target], seq_length)

# # Shuffle training data
# X_train, y_train = shuffle(X_train, y_train, random_state=42)

# --------------------------------------
# ✅ Step 4: Handle class imbalance
# --------------------------------------
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(enumerate(weights))
# --------------------------------------
# ✅ Step 5: Build LSTM model
# Changed: Explicit `Input()` layer added to fix Keras warning
# --------------------------------------
model = Sequential([
    Input(shape=(seq_length, len(features))),
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation="relu"),
    Dense(1, activation="sigmoid")  # Binary classification
])

# --------------------------------------
# ✅ Step 6: Compile and train with early stopping
# --------------------------------------
model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.001), metrics=["accuracy"])

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stop],
    class_weight=class_weights  # Handles imbalance
)

# --------------------------------------
# ✅ Step 7: Evaluate and report directional accuracy
# --------------------------------------
test_loss, test_acc = model.evaluate(X_test, y_test)
y_pred = (model.predict(X_test) > 0.5).astype(int)

directional_acc = np.mean(y_pred.flatten() == y_test)
print(f"Test Accuracy: {test_acc:.2f}")
print(f"Directional Accuracy: {directional_acc:.2f}")
# Out:
# Epoch 1/50
# 1406/1406 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.5039 - loss: 0.6938 - val_accuracy: 0.5031 - val_loss: 0.6931
# Epoch 2/50
# 1406/1406 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.5086 - loss: 0.6926 - val_accuracy: 0.5055 - val_loss: 0.6932
# Epoch 3/50
# 1406/1406 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.5118 - loss: 0.6928 - val_accuracy: 0.5087 - val_loss: 0.6930
# Epoch 4/50
# 1406/1406 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.5127 - loss: 0.6926 - val_accuracy: 0.4979 - val_loss: 0.6948
# Epoch 5/50
# 1406/1406 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.5179 - loss: 0.6920 - val_accuracy: 0.5020 - val_loss: 0.6939
# Epoch 6/50
# 1406/1406 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.5211 - loss: 0.6916 - val_accuracy: 0.4946 - val_loss: 0.6948
# Epoch 7/50
# 1406/1406 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.5206 - loss: 0.6910 - val_accuracy: 0.4993 - val_loss: 0.6946
# Epoch 8/50
# 1406/1406 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.5235 - loss: 0.6903 - val_accuracy: 0.4971 - val_loss: 0.6955
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5053 - loss: 0.6930
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Test Accuracy: 0.51
# Directional Accuracy: 0.51

# %%
# Select features and target
features = ["Close", "High", "Low", "Open", "Volume", "log_return"]
target = ["log_return"]

# Normalize features
scaler = StandardScaler()
train_df[features] = scaler.fit_transform(train_df[features])
val_df[features] = scaler.transform(val_df[features])
test_df[features] = scaler.transform(test_df[features])

# Create sequences
seq_length = 10
X_train, y_train = create_sequences(train_df[features + target], seq_length)
X_val, y_val = create_sequences(val_df[features + target], seq_length)
X_test, y_test = create_sequences(test_df[features + target], seq_length)

# Shuffle training data
X_train, y_train = shuffle(X_train, y_train, random_state=42)

# Define model builder function for Keras Tuner
def build_model(hp):
    model = Sequential()
    model.add(LSTM(
        units=hp.Int("lstm_units_1", min_value=32, max_value=128, step=32),
        return_sequences=True, input_shape=(seq_length, len(features))
    ))
    model.add(Dropout(hp.Float("dropout_1", 0.1, 0.5, step=0.1)))

    model.add(LSTM(
        units=hp.Int("lstm_units_2", min_value=16, max_value=64, step=16),
        return_sequences=False
    ))
    model.add(Dropout(hp.Float("dropout_2", 0.1, 0.5, step=0.1)))

    model.add(Dense(
        units=hp.Int("dense_units", min_value=8, max_value=32, step=8),
        activation="relu"
    ))

    model.add(Dense(1, activation="sigmoid"))  # Binary classification

    model.compile(
        loss="binary_crossentropy",
        optimizer=Adam(hp.Choice("learning_rate", [0.001, 0.0005, 0.0001])),
        metrics=["accuracy"]
    )

    return model

# Initialize Keras Tuner
tuner = kt.Hyperband(
    build_model,
    objective="val_accuracy",
    max_epochs=20,
    factor=3,
    directory="kt_lstm_tuning",
    project_name="lstm_stock_prediction"
)

# Perform hyperparameter search
tuner.search(X_train, y_train, epochs=10, validation_data=(X_val, y_val), batch_size=32)

# Get the best model
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build and train the final model
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val, y_val))

# Evaluate on test data
test_loss, test_acc = best_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")

# Predictions
y_pred = (best_model.predict(X_test) > 0.5).astype(int)

# Calculate model accuracy based on actual next day Open & Close prices
def calculate_accuracy(test_df, y_pred, seq_length):
    correct_predictions = 0
    total_samples = len(y_pred)

    for i in range(seq_length, len(test_df) - 1):
        actual_position = 1 if test_df.iloc[i + 1]['Close'] > test_df.iloc[i + 1]['Open'] else 0
        predicted_position = y_pred[i - seq_length]
        if actual_position == predicted_position:
            correct_predictions += 1

    return correct_predictions / total_samples

# Compute and print accuracy
final_accuracy = calculate_accuracy(test_df, y_pred, seq_length)
print(f"Final Model Accuracy: {final_accuracy:.2f}")
# Out:
# Trial 30 Complete [00h 11m 07s]
# val_accuracy: 0.5132313966751099
#
# Best val_accuracy So Far: 0.519481360912323
# Total elapsed time: 02h 01m 30s
# Epoch 1/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.5000 - loss: 0.6948 - val_accuracy: 0.4938 - val_loss: 0.6938
# Epoch 2/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 39s 26ms/step - accuracy: 0.5037 - loss: 0.6935 - val_accuracy: 0.4970 - val_loss: 0.6934
# Epoch 3/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 42s 26ms/step - accuracy: 0.5087 - loss: 0.6931 - val_accuracy: 0.5066 - val_loss: 0.6929
# Epoch 4/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.5124 - loss: 0.6926 - val_accuracy: 0.5095 - val_loss: 0.6930
# Epoch 5/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 38s 27ms/step - accuracy: 0.5088 - loss: 0.6932 - val_accuracy: 0.5116 - val_loss: 0.6924
# Epoch 6/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 38s 25ms/step - accuracy: 0.5155 - loss: 0.6924 - val_accuracy: 0.5087 - val_loss: 0.6929
# Epoch 7/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 43s 26ms/step - accuracy: 0.5161 - loss: 0.6921 - val_accuracy: 0.5061 - val_loss: 0.6934
# Epoch 8/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 40s 25ms/step - accuracy: 0.5179 - loss: 0.6917 - val_accuracy: 0.5102 - val_loss: 0.6938
# Epoch 9/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 42s 26ms/step - accuracy: 0.5238 - loss: 0.6906 - val_accuracy: 0.5137 - val_loss: 0.6943
# Epoch 10/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 40s 25ms/step - accuracy: 0.5230 - loss: 0.6896 - val_accuracy: 0.5161 - val_loss: 0.6950
# Epoch 11/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 42s 26ms/step - accuracy: 0.5267 - loss: 0.6882 - val_accuracy: 0.5098 - val_loss: 0.6948
# Epoch 12/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.5268 - loss: 0.6877 - val_accuracy: 0.5064 - val_loss: 0.6948
# Epoch 13/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.5295 - loss: 0.6871 - val_accuracy: 0.5072 - val_loss: 0.6970
# Epoch 14/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 40s 25ms/step - accuracy: 0.5259 - loss: 0.6853 - val_accuracy: 0.5019 - val_loss: 0.6981
# Epoch 15/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.5323 - loss: 0.6852 - val_accuracy: 0.5033 - val_loss: 0.7011
# Epoch 16/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.5266 - loss: 0.6828 - val_accuracy: 0.5101 - val_loss: 0.6961
# Epoch 17/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.5397 - loss: 0.6800 - val_accuracy: 0.5147 - val_loss: 0.6969
# Epoch 18/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step - accuracy: 0.5413 - loss: 0.6794 - val_accuracy: 0.5070 - val_loss: 0.7042
# Epoch 19/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 41s 25ms/step - accuracy: 0.5442 - loss: 0.6760 - val_accuracy: 0.5109 - val_loss: 0.7045
# Epoch 20/20
# 1414/1414 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.5480 - loss: 0.6742 - val_accuracy: 0.5074 - val_loss: 0.7062
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5096 - loss: 0.7122
# Test Accuracy: 0.51
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step
# Final Model Accuracy: 0.50
